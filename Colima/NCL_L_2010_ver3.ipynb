# %% [markdown]
# <a href="https://colab.research.google.com/github/Naylet92/Estudio_ambiental/blob/main/Colima/NCL_L_2010_ver3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DESCRIPCIÓN DEL PROCESAMIENTO DE IMÁGENES LANDSAT 5 Y 7 (AÑO 2010)

# %% [markdown]
# #1. Información general del área de estudio
# El análisis se realizó al Parque Estatal Bosque Mesofilo Nevado de Colima, localizada en el estado de Jalisco, México. Se utilizaron imágenes de las colecciones Landsat 5 TM Collection 2 Level-2 y Landsat 7 ETM+ Collection 2 Level-2 (reflectancia superficial) correspondientes al año 2010.
#
# Se definieron dos temporadas de estudio para analizar la variabilidad fenológica de la vegetación:
#
# Temporada seca: 1 de marzo al 31 de mayo.--------> Evaluar condiciones de estrés hídrico y vegetación en estiaje
#
# Temporada húmeda: 1 de agosto al 30 de noviembre.--------> Evaluar el máximo desarrollo vegetal post-lluvias

# %% [markdown]
# #2. Disponibilidad de imágenes por sensor
# ***Landsat 5 TM***
#
# No se encontraron imágenes disponibles para el año 2010 en el área de estudio.
#
# Resultado:
#
# Temporada seca (marzo-mayo): 0 imágenes
#
# Temporada húmeda (junio-diciembre): 0 imágenes
#
# Posibles causas:
#
# Escasa cobertura de Landsat 5 sobre la región en 2010
#
# Preferencia de adquisición hacia Landsat 7 tras el fallo del SLC en 2003
#
# Cobertura de nubes que redujo las escenas útiles
#
# ***Landsat 7 ETM+***
#
# Se encontraron imágenes disponibles para ambas temporadas, con buena cobertura temporal:
#
# Temporada seca (6 imágenes)
#
# | 🌦️ Temporada | 📅 Rango de fechas | 📷 Imágenes | 🗓️ Fechas de adquisición |
# |-------------|-------------------|-------------|-------------------------|
# | **Seca** | 01/03 – 31/05 | 4 | `2010-03-22` · `2010-04-07` · `2010-05-09` · `2010-05-25`|
# | **Húmeda** | 01/08 – 30/11 | 6 | `2010-08-29` · `2010-09-14` · `2010-09-30` · `2010-10-16` · `2010-11-01` · `2010-11-17`|

# %% [markdown]
# #3. Procesamiento aplicado (Landsat 7)
#
# 3.1. El flujo de procesamiento incluyó las siguientes etapas, implementadas mediante código en Google Earth Engine:
#
# Se utilizó la banda de calidad QA_PIXEL para excluir píxeles afectados por nubes y sombras, asegurando que solo información válida contribuyera al mosaico final.
#
# 3.2. Corrección topográfica
#
# Se aplicó una corrección por iluminación topográfica utilizando el modelo digital de elevación SRTM (30 m). El método corrige las diferencias de iluminación causadas por la pendiente y orientación del terreno, normalizando las reflectancias con el ángulo solar y el coseno del ángulo de incidencia.
#
# 3.3. Composición de mediana
#
# Para cada temporada se generó un mosaico de mediana utilizando todas las imágenes disponibles. Este enfoque reduce el ruido y minimiza la influencia de artefactos residuales de nubes o sombras.
#
# 3.4. Cálculo de índices y componentes
#
# A partir del mosaico de mediana se derivaron:
#
# NDVI (Índice de Vegetación de Diferencia Normalizada)
# NDVI = (NIR - Rojo) / (NIR + Rojo)
#
# Componentes de Tasseled Cap (Brightness, Greenness, Wetness) Utilizando los coeficientes estándar para Landsat 7 ETM+ obtenidos de la USGS:
#
# | Componente | B1 (Azul) | B2 (Verde) | B3 (Rojo) | B4 (NIR) | B5 (SWIR1) | B7 (SWIR2) |
# |------------|-----------|------------|-----------|----------|------------|------------|
# | **Brightness** | 0.3561 | 0.3972 | 0.3904 | 0.6966 | 0.2286 | 0.1596 |
# | **Greenness** | -0.3344 | -0.3544 | -0.4556 | 0.6966 | -0.0242 | -0.2630 |
# | **Wetness** | 0.2626 | 0.2141 | 0.0926 | 0.0656 | -0.7629 | -0.5388 |

# %% [markdown]
# #4. Resultados estadísticos por temporada
#
# | Variable | Temporada | Mínimo | Máximo | Paleta | Interpretación del rango |
# |----------|-----------|--------|--------|--------|--------------------------|
# | **NDVI** | Seca | 0.12 | 0.90 | Rojo → Amarillo → Verde | Mínimo positivo (0.12) indica ausencia de cuerpos de agua permanentes. Valores altos (0.70-0.90) reflejan vegetación saludable con cierto estrés hídrico durante la seca. |
# | | Húmeda | 0.13 | **1.09** | Rojo → Amarillo → Verde | **NDVI superior a 1.0** (inusualmente alto), sugiere posible saturación del sensor o valores anómalos en áreas de vegetación muy densa. |
# | **TC Brightness** | Seca | 0.001 | 1.38 | Blanco → Café | Brillos moderados. Valores altos (1.00-1.38) indican suelos expuestos y vegetación sin follaje durante la estación seca. |
# | | Húmeda | 0.001 | 1.79 | Blanco → Café | Incremento del brillo (+0.41), reflejando mayor reflectancia de la vegetación densa y húmeda. |
# | **TC Greenness** | Seca | -0.06 | 0.75 | Blanco → Verde oscuro | Valores ligeramente negativos indican pequeñas áreas sin vegetación activa. Valores altos (0.55-0.75) reflejan vegetación vigorosa. |
# | | Húmeda | -0.04 | 0.79 | Blanco → Verde oscuro | Leve incremento (+0.04) en Greenness máximo. Respuesta fenológica menos marcada que en otros años. |
# | **TC Wetness** | Seca | **-0.75** | -0.0003 | Café → Blanco → Azul | **Todos los valores negativos**, indicando condiciones secas dominantes. Ausencia total de humedad superficial positiva. |
# | | Húmeda | **-0.79** | -0.0003 | Café → Blanco → Azul | **Todos los valores negativos**, sorprendentemente más secos que en temporada seca. Posible anomalía en datos o procesamiento. |

# %% [markdown]
# ##5. Comparación de resultados
# | Componente | Rango obtenido (seca) | Rango obtenido (húmeda) | Diagnóstico |
# |------------|----------------------|------------------------|-------------|
# | **NDVI** | 0.12 - 0.90 | 0.13 - 1.09 | ⚠️ Rango expandido artificialmente en húmeda por sobre-corrección |
# | **TC Brightness** | 0.001 - 1.38 | 0.001 - 1.79 | ⚠️ Brillos más altos de lo esperado, especialmente en húmeda |
# | **TC Greenness** | -0.06 - 0.75 | -0.04 - 0.79 | ✅ Rango normal, buena respuesta fenológica |
# | **TC Wetness** | -0.75 - 0.00 | -0.79 - 0.00 | 🔴 **Completamente negativo**, sin valores positivos de humedad |

# %% [markdown]
# ## Selección y procesamiento de imágenes Landsat (año 2010)

# %% [markdown]
# ##Definir Variables

# %%
# Prefijo del área
PREFIJO     = 'NCL'
# Nombre del área
NOMBRE      = 'Nevado_Colima'

# Carpeta de salida en Drive
#RUTA_AOI    = '/content/drive/MyDrive/ANP/AOI/Colima'
RUTA_AOI    = '/content/drive/MyDrive/Colab Data/Naylet/AOI'

# Rutas
RUTA_GEOJSON = f'{RUTA_AOI}/aoi_{PREFIJO}.geojson'
RUTA_BBOX   = f'{RUTA_AOI}/{PREFIJO}_bbox.geojson'
RUTA_CSV    = f'{RUTA_AOI}/{PREFIJO}_coordenadas.csv'

# CRS geográfico y UTM
CRS_GEO     = 4326
CRS_UTM     = 32613

# Proyecto de Google Earth Engine
#GEE_PROJECT = 'ee-nayleths'
GEE_PROJECT = 'ee-vshalisko'

AÑO           = 2010
COLECCION_L5     = 'LANDSAT/LT05/C02/T1_L2'
COLECCION_L5_T2     = 'LANDSAT/LT05/C02/T2_L2'
COLECCION_L7    = 'LANDSAT/LE07/C02/T1_L2'

# Temporadas de análisis
TEMPORADA_SECA   = ('03-01', '05-31')
TEMPORADA_HUMEDA = ('08-01', '11-30')

# Bandas espectrales de reflectancia superficial (Landsat 5 y 7)
BANDAS_SR     = ['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']
BANDAS_CORR   = [b + '_corr' for b in BANDAS_SR]

# Coeficientes Tasseled Cap (Landsat 7 ETM+)
TC_BRIGHT = [0.3561, 0.3972, 0.3904, 0.6966, 0.2286, 0.1596]
TC_GREEN  = [-0.3344, -0.3544, -0.4556, 0.6966, -0.0242, -0.2630]
TC_WET    = [0.2626, 0.2141, 0.0926, 0.0656, -0.7629, -0.5388]

# Escala de exportación (m)
ESCALA        = 30

# Zoom inicial del mapa
ZOOM        = 12

# Estilo del área de estudio
STYLE_AREA  = {'color': 'blue', 'fillColor': '#0000ff30', 'weight': 1.5}

# Estilo del rectángulo rojo o bounding box
STYLE_BBOX  = {'color': 'red', 'fillColor': '#00000000', 'weight': 2.5}

# Título del mapa
MAP_TITLE   = 'Área de estudio Nevado de Colima'

# Carpeta de salida en Drive para imágenes GEE
#RUTA_IMAGENES = f'/content/drive/MyDrive/ANP/Landsat'
RUTA_IMAGENES = 'Colab Data NDC 2020'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import ee
import os
import math
import json
import geemap
import pandas as pd
import geopandas as gpd
from shapely.geometry import box
from google.colab import drive
from IPython.display import display, HTML

# Montar Google Drive
drive.mount('/content/drive')

# Autenticar e inicializar GEE
ee.Authenticate()
ee.Initialize(project=GEE_PROJECT)

print("✓ Entorno listo")
# Out:
# Mounted at /content/drive
# ✓ Entorno listo

# %%
# Enmascarar nubes y sombras
def mask_clouds(image):
    qa = image.select('QA_PIXEL')
    cloud_shadow_mask = qa.bitwiseAnd(1 << 3).eq(0)
    cloud_mask        = qa.bitwiseAnd(1 << 4).eq(0)
    return image.updateMask(cloud_shadow_mask.And(cloud_mask))


def correccion_topografica(image, region):
    dem        = ee.Image('USGS/SRTMGL1_003').clip(region)
    terreno    = ee.Terrain.products(dem)

    pendiente   = terreno.select('slope').multiply(math.pi / 180)
    orientacion = terreno.select('aspect').multiply(math.pi / 180)

    az_solar   = ee.Number(image.get('SUN_AZIMUTH')).multiply(math.pi / 180)
    elev_solar = ee.Number(image.get('SUN_ELEVATION')).multiply(math.pi / 180)

    cos_i = (
        pendiente.cos().multiply(elev_solar.sin())
        .add(
            pendiente.sin()
            .multiply(elev_solar.cos())
            .multiply(orientacion.subtract(az_solar).cos())
        )
    )
    cos_i_safe = cos_i.max(0.2)

    # Factor de escala para Collection 2 (DN * 0.0000275 - 0.2)
    cos_i_stack = cos_i_safe.rename('cos_i')
    im_bandas = image.select(BANDAS_SR).multiply(0.0000275).add(-0.2)

    bandas_corr = (
    ee.Image.cat([
        im_bandas.select(b).divide(cos_i_stack).rename(BANDAS_CORR[i])
        for i, b in enumerate(BANDAS_SR)
        ])
        .set('SUN_AZIMUTH',   image.get('SUN_AZIMUTH'))
        .set('SUN_ELEVATION', image.get('SUN_ELEVATION'))
        .cast({b: 'double' for b in BANDAS_CORR})
    )

    return bandas_corr


def tasseled_cap(image_corr, coefs, nombre):
    partes = ee.Image.cat([
        image_corr.select(b).multiply(c)
        for b, c in zip(BANDAS_CORR, coefs)
    ])
    return partes.reduce(ee.Reducer.sum()).rename(nombre)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Región GEE desde el GeoJSON generado
gdf = gpd.read_file(RUTA_BBOX)
geojson_str = gdf.to_crs(epsg=CRS_GEO).to_json()
region = ee.FeatureCollection(json.loads(geojson_str)).geometry()

def procesar_temporada(nombre_temporada, fecha_ini, fecha_fin):
    print(f"\n── Temporada: {nombre_temporada} ({fecha_ini} → {fecha_fin}) ──")

    fecha_inicio_exacto = f'{AÑO}-{fecha_ini}'
    fecha_fin_exacto   = f'{AÑO}-{fecha_fin}'

    YEAR_BEFORE = AÑO - 1
    YEAR_AFTER = AÑO + 1

    fecha_inicio_anterior = f'{YEAR_BEFORE}-{fecha_ini}'
    fecha_fin_anterior    = f'{YEAR_BEFORE}-{fecha_fin}'
    fecha_inicio_posterior = f'{YEAR_AFTER}-{fecha_ini}'
    fecha_fin_posterior    = f'{YEAR_AFTER}-{fecha_fin}'

    # Cargar colecciones L5 y L7 por separado
    col_l5_exacto = (ee.ImageCollection(COLECCION_L5)
                .filterDate(fecha_inicio_exacto, fecha_fin_exacto)
                .filterBounds(region))

    col_l5_exacto_t2 = (ee.ImageCollection(COLECCION_L5_T2)
                .filterDate(fecha_inicio_exacto, fecha_fin_exacto)
                .filterBounds(region))

    col_l7_exacto = (ee.ImageCollection(COLECCION_L7)
                .filterDate(fecha_inicio_exacto, fecha_fin_exacto)
                .filterBounds(region))

    # Cargar colecciones L5 y L7 por separado de año anterior y posterior
    col_l5_anterior = (ee.ImageCollection(COLECCION_L5)
                .filterDate(fecha_inicio_anterior, fecha_fin_anterior)
                .filterBounds(region))

    col_l7_anterior = (ee.ImageCollection(COLECCION_L7)
                .filterDate(fecha_inicio_anterior, fecha_fin_anterior)
                .filterBounds(region))

    # Cargar colecciones L5 y L7 por separado de año anterior y posterior
    col_l5_posterior = (ee.ImageCollection(COLECCION_L5)
                .filterDate(fecha_inicio_posterior, fecha_fin_posterior)
                .filterBounds(region))

    col_l7_posterior = (ee.ImageCollection(COLECCION_L7)
                .filterDate(fecha_inicio_posterior, fecha_fin_posterior)
                .filterBounds(region))

    # Combianar datos
    col_l5 = col_l5_exacto.merge(col_l5_exacto_t2).merge(col_l5_anterior).merge(col_l5_posterior)
    col_l7 = col_l7_exacto.merge(col_l7_anterior).merge(col_l7_posterior)


    info = col_l7.aggregate_array('LANDSAT_PRODUCT_ID').getInfo()
    for i in info:
      print(i)
      paths = col_l7.aggregate_array('WRS_PATH').getInfo()
      rows  = col_l7.aggregate_array('WRS_ROW').getInfo()

    for p, r in zip(paths, rows):
      print(f'Path: {p}, Row: {r}')

    n_l5 = col_l5.size().getInfo()
    n_l7 = col_l7.size().getInfo()

    print(f"  Imágenes Landsat 5: {n_l5}")
    if n_l5 > 0:
        fechas_l5 = col_l5.aggregate_array('DATE_ACQUIRED').getInfo()
        for f in sorted(fechas_l5):
            print(f"    · L5 {f}")
    else:
        print("    Sin imágenes L5")

    print(f"  Imágenes Landsat 7: {n_l7}")
    if n_l7 > 0:
        fechas_l7 = col_l7.aggregate_array('DATE_ACQUIRED').getInfo()
        for f in sorted(fechas_l7):
            print(f"    · L7 {f}")
    else:
        print("    Sin imágenes L7")

    #  Procesar L5 si hay imágenes
    img_l5 = None
    mosaico_l5 = None
    if n_l5 > 0:
        col_l5_limpia = col_l5.map(mask_clouds).map(lambda img: correccion_topografica(img, region))
        col_l5_corr = col_l5_limpia.select(BANDAS_CORR)
        mosaico_l5 = col_l5_corr.median().clip(region)
        img_l5 = procesar_bandas(mosaico_l5)
        print(f"  L5 procesado correctamente")
    else:
        print(f"  L5: Sin datos para esta temporada")

    #  Procesar L7 si hay imágenes
    img_l7 = None
    mosaico_l7 = None
    if n_l7 > 0:
        col_l7_limpia = col_l7.map(mask_clouds).map(lambda img: correccion_topografica(img, region))
        col_l7_corr = col_l7_limpia.select(BANDAS_CORR)
        mosaico_l7 = col_l7_corr.median().clip(region)
        img_l7 = procesar_bandas(mosaico_l7)
        print(f"  L7 procesado correctamente")
    else:
        print(f"  L7: Sin datos para esta temporada")


    return img_l5, img_l7, mosaico_l5, mosaico_l7

def procesar_bandas(mosaico):
    """Función auxiliar para calcular NDVI y Tasseled Cap"""
    # ── NDVI
    nir  = mosaico.select('SR_B4_corr')
    red  = mosaico.select('SR_B3_corr')
    ndvi = nir.subtract(red).divide(nir.add(red)).rename('NDVI')

    # ── Tasseled Cap
    tc_b = tasseled_cap(mosaico, TC_BRIGHT, 'TC_Brightness')
    tc_g = tasseled_cap(mosaico, TC_GREEN,  'TC_Greenness')
    tc_w = tasseled_cap(mosaico, TC_WET,    'TC_Wetness')

    resultado = (ee.Image.cat([ndvi, tc_b, tc_g, tc_w])
                   .clip(region)
                   .cast({'NDVI': 'double', 'TC_Brightness': 'double',
                          'TC_Greenness': 'double', 'TC_Wetness': 'double'}))
    return resultado
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Ejecutar procesamiento por sensor y temporada
img_seca_l5, img_seca_l7, mosaico_seca_l5,   mosaico_seca_l7     = procesar_temporada('Seca',   *TEMPORADA_SECA)
img_humeda_l5, img_humeda_l7, mosaico_humeda_l5, mosaico_humeda_l7 = procesar_temporada('Húmeda', *TEMPORADA_HUMEDA)


# Exportar a Google Drive
def exportar(imagen, sensor, sufijo):
    if imagen is None:
        print(f"Exportación cancelada para '{sensor}_{sufijo}': imagen no disponible.")
        return

    nombre_tarea = f'{PREFIJO}_{AÑO}_{sensor}_{sufijo}'
    tarea = ee.batch.Export.image.toDrive(
        image          = imagen,
        description    = nombre_tarea,
        folder         = RUTA_IMAGENES,
        fileNamePrefix = nombre_tarea,
        region         = region,
        scale          = ESCALA,
        crs            = f'EPSG:{CRS_UTM}',
        maxPixels      = 1e13
    )
    tarea.start()
    print(f"Tarea iniciada: {nombre_tarea}")

exportar(img_seca_l5,   'L5', 'seca')
exportar(img_seca_l7,   'L7', 'seca')
exportar(img_humeda_l5, 'L5', 'humeda')
exportar(img_humeda_l7, 'L7', 'humeda')

# Exportar bandas corregidas (SR_B1_corr … SR_B7_corr)
exportar(mosaico_seca_l5,   'L5', 'seca_bandas_corr')
exportar(mosaico_seca_l7,   'L7', 'seca_bandas_corr')
exportar(mosaico_humeda_l5, 'L5', 'humeda_bandas_corr')
exportar(mosaico_humeda_l7, 'L7', 'humeda_bandas_corr')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# WARNING:google_auth_httplib2:httplib2 transport does not support per-request timeout. Set the timeout when constructing the httplib2.Http instance.
# WARNING:google_auth_httplib2:httplib2 transport does not support per-request timeout. Set the timeout when constructing the httplib2.Http instance.
# ── Temporada: Seca (03-01 → 05-31) ──
# LE07_L2SP_029046_20100322_20200911_02_T1
# LE07_L2SP_029046_20100407_20200911_02_T1
# LE07_L2SP_029046_20100509_20200911_02_T1
# LE07_L2SP_029046_20100525_20200911_02_T1
# LE07_L2SP_029047_20100322_20200911_02_T1
# LE07_L2SP_029047_20100407_20200911_02_T1
# LE07_L2SP_029047_20100509_20200911_02_T1
# LE07_L2SP_029047_20100525_20200911_02_T1
# LE07_L2SP_029046_20090303_20200912_02_T1
# LE07_L2SP_029046_20090319_20200912_02_T1
# LE07_L2SP_029046_20090404_20200912_02_T1
# LE07_L2SP_029046_20090420_20200912_02_T1
# LE07_L2SP_029046_20090506_20200912_02_T1
# LE07_L2SP_029047_20090303_20200912_02_T1
# LE07_L2SP_029047_20090319_20200912_02_T1
# LE07_L2SP_029047_20090404_20200912_02_T1
# LE07_L2SP_029047_20090420_20200912_02_T1
# LE07_L2SP_029047_20090506_20200912_02_T1
# LE07_L2SP_029046_20110309_20200910_02_T1
# LE07_L2SP_029046_20110325_20200910_02_T1
# LE07_L2SP_029046_20110410_20200910_02_T1
# LE07_L2SP_029046_20110512_20200910_02_T1
# LE07_L2SP_029046_20110528_20200910_02_T1
# LE07_L2SP_029047_20110309_20200910_02_T1
# LE07_L2SP_029047_20110325_20200910_02_T1
# LE07_L2SP_029047_20110410_20200910_02_T1
# LE07_L2SP_029047_20110512_20200910_02_T1
# LE07_L2SP_029047_20110528_20200910_02_T1
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
#   Imágenes Landsat 5: 4
#     · L5 2011-03-01
#     · L5 2011-03-01
#     · L5 2011-04-02
#     · L5 2011-04-02
#   Imágenes Landsat 7: 28
#     · L7 2009-03-03
#     · L7 2009-03-03
#     · L7 2009-03-19
#     · L7 2009-03-19
#     · L7 2009-04-04
#     · L7 2009-04-04
#     · L7 2009-04-20
#     · L7 2009-04-20
#     · L7 2009-05-06
#     · L7 2009-05-06
#     · L7 2010-03-22
#     · L7 2010-03-22
#     · L7 2010-04-07
#     · L7 2010-04-07
#     · L7 2010-05-09
#     · L7 2010-05-09
#     · L7 2010-05-25
#     · L7 2010-05-25
#     · L7 2011-03-09
#     · L7 2011-03-09
#     · L7 2011-03-25
#     · L7 2011-03-25
#     · L7 2011-04-10
#     · L7 2011-04-10
#     · L7 2011-05-12
#     · L7 2011-05-12
#     · L7 2011-05-28
#     · L7 2011-05-28
#   L5 procesado correctamente
#   L7 procesado correctamente
#
# ── Temporada: Húmeda (08-01 → 11-30) ──
# LE07_L2SP_029046_20100829_20200910_02_T1
# LE07_L2SP_029046_20100914_20200910_02_T1
# LE07_L2SP_029046_20100930_20200911_02_T1
# LE07_L2SP_029046_20101016_20200910_02_T1
# LE07_L2SP_029046_20101101_20200910_02_T1
# LE07_L2SP_029046_20101117_20200910_02_T1
# LE07_L2SP_029047_20100914_20200910_02_T1
# LE07_L2SP_029047_20100930_20200910_02_T1
# LE07_L2SP_029047_20101016_20200910_02_T1
# LE07_L2SP_029047_20101101_20200910_02_T1
# LE07_L2SP_029047_20101117_20200910_02_T1
# LE07_L2SP_029046_20090810_20200911_02_T1
# LE07_L2SP_029046_20090826_20200911_02_T1
# LE07_L2SP_029046_20091013_20200911_02_T1
# LE07_L2SP_029046_20091114_20200911_02_T1
# LE07_L2SP_029047_20090826_20200911_02_T1
# LE07_L2SP_029047_20090911_20200912_02_T1
# LE07_L2SP_029047_20091013_20200911_02_T1
# LE07_L2SP_029047_20091029_20200911_02_T1
# LE07_L2SP_029047_20091114_20200911_02_T1
# LE07_L2SP_029046_20110816_20200909_02_T1
# LE07_L2SP_029046_20110917_20200909_02_T1
# LE07_L2SP_029046_20111003_20200909_02_T1
# LE07_L2SP_029046_20111019_20200909_02_T1
# LE07_L2SP_029046_20111104_20200909_02_T1
# LE07_L2SP_029046_20111120_20200909_02_T1
# LE07_L2SP_029047_20110816_20200910_02_T1
# LE07_L2SP_029047_20110917_20200910_02_T1
# LE07_L2SP_029047_20111003_20200909_02_T1
# LE07_L2SP_029047_20111019_20200909_02_T1
# LE07_L2SP_029047_20111104_20200909_02_T1
# LE07_L2SP_029047_20111120_20200909_02_T1
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 46
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
# Path: 29, Row: 47
#   Imágenes Landsat 5: 0
#     Sin imágenes L5
#   Imágenes Landsat 7: 32
#     · L7 2009-08-10
#     · L7 2009-08-26
#     · L7 2009-08-26
#     · L7 2009-09-11
#     · L7 2009-10-13
#     · L7 2009-10-13
#     · L7 2009-10-29
#     · L7 2009-11-14
#     · L7 2009-11-14
#     · L7 2010-08-29
#     · L7 2010-09-14
#     · L7 2010-09-14
#     · L7 2010-09-30
#     · L7 2010-09-30
#     · L7 2010-10-16
#     · L7 2010-10-16
#     · L7 2010-11-01
#     · L7 2010-11-01
#     · L7 2010-11-17
#     · L7 2010-11-17
#     · L7 2011-08-16
#     · L7 2011-08-16
#     · L7 2011-09-17
#     · L7 2011-09-17
#     · L7 2011-10-03
#     · L7 2011-10-03
#     · L7 2011-10-19
#     · L7 2011-10-19
#     · L7 2011-11-04
#     · L7 2011-11-04
#     · L7 2011-11-20
#     · L7 2011-11-20
#   L5: Sin datos para esta temporada
#   L7 procesado correctamente
# Tarea iniciada: NCL_2010_L5_seca
# Tarea iniciada: NCL_2010_L7_seca
# Exportación cancelada para 'L5_humeda': imagen no disponible.
# Tarea iniciada: NCL_2010_L7_humeda
# Tarea iniciada: NCL_2010_L5_seca_bandas_corr
# Tarea iniciada: NCL_2010_L7_seca_bandas_corr
# Exportación cancelada para 'L5_humeda_bandas_corr': imagen no disponible.
# Tarea iniciada: NCL_2010_L7_humeda_bandas_corr

# %% [markdown]
# #Calcular estadisticas de capas y de indices

# %%
def calcular_estadisticas_indices(imagen, sensor, temporada):
    if imagen is None:
        print(f"  ℹ️ No hay datos para {sensor} - {temporada}")
        return
    nombre_base = f'{AÑO} {temporada} {sensor}'
    # Calcular y mostrar estadísticas
    print(f"\n{'='*60}")
    print(f"📊 Estadísticas para {nombre_base}")
    print(f"{'='*60}")

    for banda in ['NDVI', 'TC_Brightness', 'TC_Greenness', 'TC_Wetness']:
        stats = imagen.select(banda).reduceRegion(
            reducer=ee.Reducer.minMax(),
            geometry=region,
            scale=30,
            maxPixels=1e9
        ).getInfo()

        # Combine the mean and standard deviation reducers.
        reducer_comb = ee.Reducer.mean().combine(
              reducer2=ee.Reducer.stdDev(), sharedInputs=True
        )
        stats2 = imagen.select(banda).reduceRegion(
            reducer=reducer_comb,
            geometry=region,
            scale=30,
            maxPixels=1e9
        ).getInfo()

        min_val = stats.get(f'{banda}_min', 0)
        max_val = stats.get(f'{banda}_max', 0)
        mean_val = stats2.get(f'{banda}_mean', 0)
        std_val = stats2.get(f'{banda}_stdDev', 0)

        print(f"  {banda:>15}: min = {min_val:>8.4f} | max = {max_val:>8.4f} | rango = {max_val - min_val:>8.4f} | promedio = {mean_val:>8.4f} | SD = {std_val:>8.4f}")

    print(f"{'='*60}\n")


def calcular_estadisticas_bandas(imagen, sensor, temporada, bandas):
    if imagen is None:
        print(f"  ℹ️ No hay datos para {sensor} - {temporada}")
        return
    nombre_base = f'{AÑO} {temporada} {sensor}'
    # Calcular y mostrar estadísticas
    print(f"\n{'='*60}")
    print(f"📊 Estadísticas para {nombre_base}")
    print(f"{'='*60}")

    for banda in bandas:
        stats = imagen.select(banda).reduceRegion(
            reducer=ee.Reducer.minMax(),
            geometry=region,
            scale=30,
            maxPixels=1e9
        ).getInfo()

        # Combine the mean and standard deviation reducers.
        reducer_comb = ee.Reducer.mean().combine(
              reducer2=ee.Reducer.stdDev(), sharedInputs=True
        )
        stats2 = imagen.select(banda).reduceRegion(
            reducer=reducer_comb,
            geometry=region,
            scale=30,
            maxPixels=1e9
        ).getInfo()

        min_val = stats.get(f'{banda}_min', 0)
        max_val = stats.get(f'{banda}_max', 0)
        mean_val = stats2.get(f'{banda}_mean', 0)
        std_val = stats2.get(f'{banda}_stdDev', 0)

        print(f"  {banda:>15}: min = {min_val:>8.4f} | max = {max_val:>8.4f} | rango = {max_val - min_val:>8.4f} | promedio = {mean_val:>8.4f} | SD = {std_val:>8.4f}")

    print(f"{'='*60}\n")


print("Agregando capas al mapa (2010):")
calcular_estadisticas_indices(img_seca_l7, 'L7', 'Seca')
calcular_estadisticas_bandas(mosaico_seca_l7, 'L7', 'Seca', BANDAS_CORR)

calcular_estadisticas_indices(img_humeda_l7, 'L7', 'Húmeda')
calcular_estadisticas_bandas(mosaico_humeda_l7, 'L7', 'Húmeda', BANDAS_CORR)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Agregando capas al mapa (2010):
#
# ============================================================
# 📊 Estadísticas para 2010 Seca L7
# ============================================================
#              NDVI: min =  -0.0161 | max =   0.8949 | rango =   0.9109 | promedio =   0.6215 | SD =   0.1831
#     TC_Brightness: min =   0.0014 | max =   1.5267 | rango =   1.5253 | promedio =   0.3457 | SD =   0.0696
#      TC_Greenness: min =  -0.3394 | max =   0.7476 | rango =   1.0870 | promedio =   0.1056 | SD =   0.0720
#        TC_Wetness: min =  -0.9409 | max =  -0.0010 | rango =   0.9399 | promedio =  -0.1679 | SD =   0.0595
# ============================================================
#
#
# ============================================================
# 📊 Estadísticas para 2010 Seca L7
# ============================================================
#        SR_B1_corr: min =   0.0148 | max =   0.4330 | rango =   0.4182 | promedio =   0.0447 | SD =   0.0216
#        SR_B2_corr: min =   0.0190 | max =   0.5105 | rango =   0.4915 | promedio =   0.0653 | SD =   0.0249
#        SR_B3_corr: min =   0.0136 | max =   0.6431 | rango =   0.6295 | promedio =   0.0702 | SD =   0.0374
#        SR_B4_corr: min =   0.0678 | max =   1.5046 | rango =   1.4368 | promedio =   0.3030 | SD =   0.0703
#        SR_B5_corr: min =   0.0329 | max =   1.0742 | rango =   1.0413 | promedio =   0.2072 | SD =   0.0594
#        SR_B7_corr: min =   0.0196 | max =   0.7930 | rango =   0.7733 | promedio =   0.1154 | SD =   0.0499
# ============================================================
#
#
# ============================================================
# 📊 Estadísticas para 2010 Húmeda L7
# ============================================================
#              NDVI: min =  -0.0023 | max =   1.0466 | rango =   1.0489 | promedio =   0.7729 | SD =   0.1534
#     TC_Brightness: min =   0.0013 | max =   1.8623 | rango =   1.8610 | promedio =   0.3499 | SD =   0.0866
#      TC_Greenness: min =  -0.2745 | max =   1.0446 | rango =   1.3191 | promedio =   0.1643 | SD =   0.0730
#        TC_Wetness: min =  -0.8195 | max =  -0.0006 | rango =   0.8190 | promedio =  -0.1447 | SD =   0.0423
# ============================================================
#
#
# ============================================================
# 📊 Estadísticas para 2010 Húmeda L7
# ============================================================
#        SR_B1_corr: min =   0.0000 | max =   0.4192 | rango =   0.4192 | promedio =   0.0342 | SD =   0.0201
#        SR_B2_corr: min =   0.0039 | max =   0.4350 | rango =   0.4312 | promedio =   0.0527 | SD =   0.0224
#        SR_B3_corr: min =  -0.0078 | max =   0.5309 | rango =   0.5387 | promedio =   0.0434 | SD =   0.0292
#        SR_B4_corr: min =   0.0593 | max =   1.9770 | rango =   1.9177 | promedio =   0.3487 | SD =   0.0954
#        SR_B5_corr: min =   0.0185 | max =   0.9944 | rango =   0.9760 | promedio =   0.1876 | SD =   0.0488
#        SR_B7_corr: min =   0.0047 | max =   0.5910 | rango =   0.5862 | promedio =   0.0908 | SD =   0.0352
# ============================================================

# %% [markdown]
# ### Visualización de imágenes procesadas

# %%
# Recalcular centroide
gdf_bbox = gpd.read_file(RUTA_BBOX).to_crs(epsg=CRS_GEO)
gdf_area = gpd.read_file(RUTA_GEOJSON).to_crs(epsg=CRS_GEO)


# Calcular centroide en WGS84
# FIX: calcular centroide en CRS proyectado, luego volver a WGS84
centroid_proj = gdf_bbox.to_crs(epsg=3857).dissolve().centroid.iloc[0]
centroid = gpd.GeoSeries([centroid_proj], crs=3857).to_crs(epsg=4326).iloc[0]

#  MAPA
mapa = geemap.Map(height="950px", width="100%",layer_ctrl=False)
mapa.add_gdf(gdf,      layer_name='ANP – Polígono',    style=STYLE_AREA)
mapa.centerObject(region, zoom=ZOOM)
mapa.add_gdf(gdf_bbox, layer_name='ANP – Bounding Box', style=STYLE_BBOX)
mapa.add_basemap('ROADMAP')

# Landsat 5 TM (2010)
#No hay imagenes landsat 5 tm para el año 2010, pero hay para 2011
# Temporada SECA (basado en valores calculados)
VIS_L5_SECA = {
    'NDVI': {'min': -0.10, 'max': 0.73, 'palette': ['#d73027', '#fee08b', '#1a9850']},
    'TC_Brightness': {'min': 0.00, 'max': 0.80, 'palette': ['white', 'brown']},
    'TC_Greenness': {'min': -0.13, 'max': 0.23, 'palette': ['white', 'darkgreen']},
    'TC_Wetness': {'min': -0.33, 'max': 0.30, 'palette': ['brown', 'white', 'blue']}
}

# Temporada HÚMEDA (basado en valores calculados)
VIS_L5_HUMEDA = {
    'NDVI': {'min': -0.13, 'max': 0.90, 'palette': ['#d73027', '#fee08b', '#1a9850']},
    'TC_Brightness': {'min': 0.00, 'max': 2.72, 'palette': ['white', 'brown']},
    'TC_Greenness': {'min': -0.45, 'max': 0.66, 'palette': ['white', 'darkgreen']},
    'TC_Wetness': {'min': -0.26, 'max': 0.19, 'palette': ['brown', 'white', 'blue']}
}

# Landsat 7 ETM+ (2010)
VIS_L7_SECA = {
    'NDVI': {'min': -0.66, 'max': 0.88, 'palette': ['#d73027', '#fee08b', '#1a9850']},
    'TC_Brightness': {'min': 0.00, 'max': 1.12, 'palette': ['white', 'brown']},
    'TC_Greenness': {'min': -0.68, 'max': 0.27, 'palette': ['white', 'darkgreen']},
    'TC_Wetness': {'min': -0.47, 'max': 0.47, 'palette': ['brown', 'white', 'blue']}
}

VIS_L7_HUMEDA = {
    'NDVI': {'min': -0.26, 'max': 0.93, 'palette': ['#d73027', '#fee08b', '#1a9850']},
    'TC_Brightness': {'min': 0.00, 'max': 0.94, 'palette': ['white', 'brown']},
    'TC_Greenness': {'min': -0.20, 'max': 0.50, 'palette': ['white', 'darkgreen']},
    'TC_Wetness': {'min': -0.44, 'max': 0.11, 'palette': ['brown', 'white', 'blue']}
}


# AGREGAR CAPAS CON PARÁMETROS DIFERENCIADOS
def agregar_capas(imagen, sensor, temporada):
    """Agrega capas al mapa con parámetros de visualización específicos por sensor y temporada"""
    if imagen is None:
        print(f"  ℹ️ No hay datos para {sensor} - {temporada}")
        return

    if sensor == 'L5':
       if temporada == 'Seca':
            vis = VIS_L5_SECA
       else:
            vis = VIS_L5_HUMEDA

    if sensor == 'L7':
       if temporada == 'Seca':
            vis = VIS_L7_SECA
       else:
            vis = VIS_L7_HUMEDA

    nombre_base = f'{AÑO} {temporada} {sensor}'


    mapa.addLayer(imagen.select('NDVI'), vis['NDVI'], f'{nombre_base} – NDVI',
                  shown=(temporada == 'Seca' and sensor == 'L7'))
    mapa.addLayer(imagen.select('TC_Brightness'), vis['TC_Brightness'],
                  f'{nombre_base} – TC Brightness', shown=False)
    mapa.addLayer(imagen.select('TC_Greenness'), vis['TC_Greenness'],
                  f'{nombre_base} – TC Greenness', shown=False)
    mapa.addLayer(imagen.select('TC_Wetness'), vis['TC_Wetness'],
                  f'{nombre_base} – TC Wetness', shown=False)

    # Calcular y mostrar estadísticas
    print(f"\n{'='*60}")
    print(f"📊 Estadísticas para {nombre_base}")
    print(f"{'='*60}")

    for banda in ['NDVI', 'TC_Brightness', 'TC_Greenness', 'TC_Wetness']:
        stats = imagen.select(banda).reduceRegion(
            reducer=ee.Reducer.minMax(),
            geometry=region,
            scale=30,
            maxPixels=1e9
        ).getInfo()

        min_val = stats.get(f'{banda}_min', 0)
        max_val = stats.get(f'{banda}_max', 0)

        print(f"  {banda:>15}: min = {min_val:>8.4f} | max = {max_val:>8.4f} | rango = {max_val - min_val:>8.4f}")

    print(f"{'='*60}\n")


print("Agregando capas al mapa:")
agregar_capas(img_seca_l5, 'L5', 'Seca')
agregar_capas(img_seca_l7, 'L7', 'Seca')
#agregar_capas(img_humeda_l5, 'L5', 'Húmeda')
agregar_capas(img_humeda_l7, 'L7', 'Húmeda')

mapa.addLayerControl()
print("\n✅ Visualización completada")
display(mapa)
