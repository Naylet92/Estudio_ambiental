# %% [markdown]
# <a href="https://colab.research.google.com/github/Naylet92/Estudio_ambiental/blob/main/Colima/NCL_L_2020_ver2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DESCRIPCIÓN DEL PROCESAMIENTODE IMÁGENES LANDSAT 7, LANDSAT 8 y SENTINEL-2 (AÑO 2020)

# %% [markdown]
# #1. Información general del área de estudio
# El análisis multitemporal y multisensor se realizó en el Parque Estatal Bosque Mesofilo Nevado de Colima, ubicada en el estado de Jalisco, México. Se utilizaron imágenes de tres sensores satelitales correspondientes al año 2020 para evaluar la dinámica de la cobertura vegetal:
#
# | Sensor | Plataforma | Resolución espacial | Colección / Nivel |
# |--------|------------|---------------------|-------------------|
# | **Landsat 7 ETM+** | Landsat 7 | 30 m | Collection 2 Level-2 |
# | **Landsat 8 OLI/TIRS** | Landsat 8 | 30 m | Collection 2 Level-2 |
# | **Sentinel-2 MSI** | Sentinel-2 | 10 m (resampleado a 30 m) | Level-2A |
#
# Temporada seca: 1 de marzo al 31 de mayo.--------> Evaluar condiciones de estrés hídrico y vegetación en estiaje
#
# Temporada húmeda: 1 de agosto al 30 de noviembre.--------> Evaluar el máximo desarrollo vegetal post-lluvias

# %% [markdown]
# #2. Imágenes utilizadas por sensor y temporada
# Landsat 7 ETM+ (2020)
# | Temporada | N° imágenes | Fechas de adquisición |
# |-----------|-------------|----------------------|
# | **Seca** | 6 | `2020-03-01`, `2020-03-17`, `2020-04-02`, `2020-04-18`, `2020-05-04`, `2020-05-20` |
# | **Húmeda** | 8 | `2020-08-08`, `2020-08-24`, `2020-09-09`, `2020-09-25`, `2020-10-11`, `2020-10-27`, `2020-11-12`, `2020-11-28` |
#
# Landsat 8 OLI/TIRS (2020)
#
# | Temporada | N° imágenes | Fechas de adquisición |
# |-----------|-------------|----------------------|
# | **Seca** | 6 | `2020-03-09`, `2020-03-25`, `2020-04-10`, `2020-04-26`, `2020-05-12`, `2020-05-28`|
# | **Húmeda** | 6 | `2020-08-16`, `2020-09-01`, `2020-09-17`, `2020-10-03`, `2020-10-19`, `2020-11-20`|
#
# Sentinel-2 MSI (2020)
#
# | Temporada | N° imágenes | Fechas de adquisición |
# |-----------|-------------|----------------------|
# | **Seca** | 16 | `2020-03-03`, `2020-03-13`, `2020-03-18`, `2020-03-23`, `2020-03-28`, `2020-04-02`, `2020-04-07`, `2020-04-12`, `2020-04-17`, `2020-04-27`, `2020-05-02`, `2020-05-07`, `2020-05-12`, `2020-05-17`, `2020-05-22`, `2020-05-27` |
# | **Húmeda** | 16 | `2020-08-05`, `2020-08-10`, `2020-08-15`, `2020-09-14`, `2020-09-24`, `2020-10-04`, `2020-10-09`, `2020-10-14`, `2020-10-19`,`2020-10-24`, `2020-10-29`,`2020-11-03`, `2020-11-13`, `2020-11-18`, `2020-11-23`, `2020-11-28`|

# %% [markdown]
# #3. Procesamiento aplicado
# El flujo de procesamiento incluyó las siguientes etapas para cada sensor:
#
# 3.1. Enmascaramiento de nubes y sombras
#
# Landsat 7 y 8: Se utilizó la banda de calidad QA_PIXEL para excluir píxeles afectados por nubes y sombras.
#
# Sentinel-2: Se utilizó la banda QA60 con las máscaras de nubes cirrus y nubes opacas.
#
# 3.2. Corrección topográfica
#
# Se aplicó una corrección por iluminación topográfica utilizando el modelo digital de elevación SRTM (30 m). El método corrige las diferencias de iluminación causadas por la pendiente y orientación del terreno, normalizando las reflectancias con el ángulo solar y el coseno del ángulo de incidencia.
#
# 3.3. Composición de mediana
#
# Para cada temporada y sensor se generó un mosaico de mediana utilizando todas las imágenes disponibles. Este enfoque reduce el ruido y minimiza la influencia de artefactos residuales de nubes o sombras.
#
# 3.4. Cálculo de índices y componentes
#
# NDVI (Índice de Vegetación de Diferencia Normalizada)---  NDVI = (NIR - Rojo) / (NIR + Rojo)
#
# Componentes de Tasseled Cap por sensor
#
# Landsat 7 ETM+
#
# | Componente | B1 | B2 | B3 | B4 | B5 | B7 |
# |------------|-----|-----|-----|-----|-----|-----|
# | **Brightness** | 0.3561 | 0.3972 | 0.3904 | 0.6966 | 0.2286 | 0.1596 |
# | **Greenness** | -0.3344 | -0.3544 | -0.4556 | 0.6966 | -0.0242 | -0.2630 |
# | **Wetness** | 0.2626 | 0.2141 | 0.0926 | 0.0656 | -0.7629 | -0.5388 |
#
# Landsat 8 OLI
#
# | Componente | B2 | B3 | B4 | B5 | B6 | B7 |
# |------------|-----|-----|-----|-----|-----|-----|
# | **Brightness** | 0.2043 | 0.2043 | 0.2171 | 0.2435 | 0.2562 | 0.1499 |
# | **Greenness** | -0.1603 | -0.1603 | 0.2482 | 0.2185 | -0.3390 | -0.3116 |
# | **Wetness** | 0.2219 | 0.2219 | 0.2353 | 0.2383 | -0.6170 | -0.4462 |
#
# Sentinel-2 MSI
#
# | Componente | B2 | B3 | B4 | B5 | B6 | B7 |
# |------------|-----|-----|-----|-----|-----|-----|
# | **Brightness** | 0.3037 | 0.2793 | 0.4743 | 0.5585 | 0.5082 | 0.1863 |
# | **Greenness** | -0.2848 | -0.2435 | -0.5436 | 0.7243 | 0.0840 | -0.1800 |
# | **Wetness** | 0.1509 | 0.1973 | 0.3279 | 0.3406 | -0.7112 | -0.4572 |

# %% [markdown]
# #4. Resultados estadísticos por sensor y temporada
#
# Landsat 7 ETM+ (2020)
#
# | Variable | Temporada | Mínimo | Máximo | Paleta | Interpretación del rango |
# |----------|-----------|--------|--------|--------|--------------------------|
# | **NDVI** | Seca | 0.18 | 0.92 | Rojo → Amarillo → Verde | Mínimo positivo (0.18) indica ausencia de cuerpos de agua. Valores altos (0.75-0.92) reflejan vegetación saludable con estrés hídrico moderado. |
# | | Húmeda | 0.18 | **1.20** | Rojo → Amarillo → Verde | ⚠️ **NDVI > 1.0 (1.20)** indica saturación del sensor o sobre-corrección topográfica en áreas de vegetación muy densa. |
# | **TC Brightness** | Seca | 0.001 | 2.22 | Blanco → Café | Brillos altos (1.80-2.22) indican suelos expuestos y alta reflectancia durante la sequía. |
# | | Húmeda | 0.001 | **3.12** | Blanco → Café | **Incremento extremo (+0.90)**. Valores > 3.0 indican sobre-corrección severa en áreas de ladera. |
# | **TC Greenness** | Seca | -0.08 | **1.19** | Blanco → Verde oscuro | Valores muy altos (0.90-1.19) reflejan vegetación extremadamente vigorosa. Mínimo ligeramente negativo indica pequeñas áreas sin vegetación. |
# | | Húmeda | -0.06 | **1.66** | Blanco → Verde oscuro | **Greenness excepcionalmente alto** (1.66), sugiere sobre-corrección o saturación del sensor. |
# | **TC Wetness** | Seca | **-1.14** | 0.01 | Café → Blanco → Azul | Condiciones extremadamente secas (mínimo -1.14). Casi sin valores positivos de humedad. |
# | | Húmeda | **-1.47** | 0.02 | Café → Blanco → Azul | **Wetness más negativo aún**, indicando severa sobre-corrección en lugar de mayor humedad. |
#
# Landsat 8 OLI (2020)
# | Variable | Temporada | Mínimo | Máximo | Paleta | Interpretación del rango |
# |----------|-----------|--------|--------|--------|--------------------------|
# | **NDVI** | Seca | 0.10 | 0.90 | Rojo → Amarillo → Verde | Rango normal. Mínimo bajo (0.10) indica pequeñas áreas de suelo desnudo. Máximo 0.90 refleja vegetación vigorosa. |
# | | Húmeda | 0.11 | **1.20** | Rojo → Amarillo → Verde | ⚠️ **NDVI > 1.0 (1.20)** al igual que L7, indica sobre-corrección topográfica generalizada. |
# | **TC Brightness** | Seca | 0.001 | 2.43 | Blanco → Café | Brillos muy altos (2.00-2.43), indicando posible sobre-corrección o suelos muy reflectantes. |
# | | Húmeda | 0.001 | 2.70 | Blanco → Café | Incremento del brillo (+0.27), consistente con vegetación densa, pero valores aún muy altos. |
# | **TC Greenness** | Seca | **-0.54** | 0.01 | Blanco → Verde oscuro | **Greenness anormalmente bajo**. Máximo cercano a cero indica ausencia de vegetación activa detectada. Posible problema en coeficientes. |
# | | Húmeda | -0.35 | 0.02 | Blanco → Verde oscuro | Greenness aún muy bajo (máx 0.02), **sin respuesta fenológica detectable**. Inconsistente con NDVI alto. |
# | **TC Wetness** | Seca | 0.0001 | 0.45 | Café → Blanco → Azul | **Todos los valores positivos** (inusual). Máximo 0.45 indica humedad superficial detectada incluso en seca. |
# | | Húmeda | -0.01 | 0.45 | Café → Blanco → Azul | Rango similar a seca. Valores positivos dominantes, sin reflejar incremento estacional de humedad. |
#
# Sentinel-2 MSI (2020)
#
# | Variable | Temporada | Mínimo | Máximo | Paleta | Interpretación del rango |
# |----------|-----------|--------|--------|--------|--------------------------|
# | **NDVI** | Seca | 0.02 | 0.91 | Rojo → Amarillo → Verde | Mínimo muy bajo (0.02) indica áreas de suelo desnudo. Máximo 0.91 refleja vegetación saludable. **Rango más realista de los tres sensores**. |
# | | Húmeda | 0.04 | 0.94 | Rojo → Amarillo → Verde | Leve incremento en NDVI (+0.03). **Sin valores anómalos > 1.0**. Comportamiento fenológico esperado. |
# | **TC Brightness** | Seca | 0.03 | 0.76 | Blanco → Café | Rango moderado y realista. Valores altos (0.60-0.76) indican suelos expuestos en temporada seca. |
# | | Húmeda | 0.03 | 0.89 | Blanco → Café | Ligero incremento (+0.13), reflejando mayor reflectancia de vegetación densa. **Sin sobre-corrección**. |
# | **TC Greenness** | Seca | -0.11 | 0.39 | Blanco → Verde oscuro | Rango normal. Valores altos (0.30-0.39) indican vegetación activa en temporada seca (especies perennifolias). |
# | | Húmeda | -0.08 | **0.53** | Blanco → Verde oscuro | **Incremento fenológico claro (+0.14)**. Valores altos (0.45-0.53) reflejan respuesta óptima a lluvias. |
# | **TC Wetness** | Seca | -0.20 | 0.04 | Café → Blanco → Azul | Rango balanceado. Valores negativos indican sequía, positivos bajos (0.04) reflejan humedad limitada. |
# | | Húmeda | -0.16 | 0.05 | Café → Blanco → Azul | Leve incremento en humedad (+0.01). Rango consistente con ecosistema de selva baja caducifolia. |

# %% [markdown]
# ##5. Comparación de resultados
# | Sensor | Temporada | NDVI | TC Brightness | TC Greenness | TC Wetness | Evaluación general |
# |--------|-----------|------|---------------|--------------|------------|-------------------|
# | **L7** | Seca | 0.18 - 0.92 | 0.001 - 2.22 | -0.08 - 1.19 | -1.14 - 0.01 | ⚠️ Sobre-corregido |
# | | Húmeda | 0.18 - 1.20 | 0.001 - 3.12 | -0.06 - 1.66 | -1.47 - 0.02 | 🔴 Valores extremos |
# | **L8** | Seca | 0.10 - 0.90 | 0.001 - 2.43 | -0.54 - 0.01 | 0.00 - 0.45 | ⚠️ Greenness anómalo |
# | | Húmeda | 0.11 - 1.20 | 0.001 - 2.70 | -0.35 - 0.02 | -0.01 - 0.45 | 🔴 Sin respuesta fenológica |
# | **S2** | Seca | 0.02 - 0.91 | 0.03 - 0.76 | -0.11 - 0.39 | -0.20 - 0.04 | ✅ Realista |
# | | Húmeda | 0.04 - 0.94 | 0.03 - 0.89 | -0.08 - 0.53 | -0.16 - 0.05 | ✅ Correcto |

# %% [markdown]
# ## Selección y procesamiento de imágenes Landsat (año 2020)

# %% [markdown]
# ##Definir Variables
#
# Notas V. Sh.:
# * Se modifico seleccion de imagenes por rectangulo delimitador en lugar de poligonos de ANP. El recorte se requiere realizar en los pasos postariores de ananlisis, no en la etapa de selección de imagenes.
# * Nombre de variable de año se modifico de AÑO a YEAR (es mejor evitar tilde en nombre de variables)
# * La ruta de carpeta donde se exportan imagenes seleccionadas y prcesadas es solo de un nivel, por limitaciones de la función exportadora de Google Drive.

# %%
PREFIJO     = 'NCL'
NOMBRE      = 'Nevado_Colima'
#RUTA_AOI    = '/content/drive/MyDrive/ANP/AOI'
RUTA_AOI    = '/content/drive/MyDrive/Colab Data/Naylet/AOI'
RUTA_GEOJSON = f'{RUTA_AOI}/aoi_{PREFIJO}.geojson'
RUTA_BBOX   = f'{RUTA_AOI}/{PREFIJO}_bbox.geojson'
RUTA_CSV    = f'{RUTA_AOI}/{PREFIJO}_coordenadas.csv'
CRS_GEO     = 4326
CRS_UTM     = 32613
#GEE_PROJECT = 'ee-nayleths'
GEE_PROJECT = 'ee-vshalisko'

YEAR             = 2020
COLECCION_L7    = 'LANDSAT/LE07/C02/T1_L2'
COLECCION_L8    = 'LANDSAT/LC08/C02/T1_L2'
COLECCION_S2    = 'COPERNICUS/S2_SR_HARMONIZED'

TEMPORADA_SECA   = ('03-01', '05-31')
TEMPORADA_HUMEDA = ('08-01', '11-30')

# Bandas L7 (igual que L5)
BANDAS_SR       = ['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']
BANDAS_CORR     = [b + '_corr' for b in BANDAS_SR]

# Bandas L8 (distinto orden: B2-B7 sin B6)
BANDAS_SR_L8    = ['SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B6', 'SR_B7']
BANDAS_CORR_L8  = [b + '_corr' for b in BANDAS_SR_L8]

# Bandas S2
BANDAS_S2       = ['B2', 'B3', 'B4', 'B8', 'B11', 'B12']

# Coeficientes Tasseled Cap L7 (mismos que L5)
TC_BRIGHT  = [0.3561, 0.3972, 0.3904, 0.6966, 0.2286, 0.1596]
TC_GREEN   = [-0.3344, -0.3544, -0.4556, 0.6966, -0.0242, -0.2630]
TC_WET     = [0.2626, 0.2141, 0.0926, 0.0656, -0.7629, -0.5388]

# Coeficientes Tasseled Cap L8
TC_BRIGHT_L8 = [0.3029, 0.2786, 0.4733, 0.5599, 0.5082, 0.1872]
TC_GREEN_L8  = [-0.2941, -0.2430, 0.5421, 0.2410, -0.5312, -0.3826]
TC_WET_L8    = [0.1511, 0.1973, 0.3283, 0.3407, -0.7117, 0.4559]

# Coeficientes Tasseled Cap S2 (from Shi & Xu, 2019)
TC_BRIGHT_S2 = [0.3037, 0.2793, 0.4743, 0.5585, 0.5082, 0.1863]
TC_GREEN_S2  = [-0.2848, -0.2435, -0.5436, 0.7243, 0.0840, -0.1800]
TC_WET_S2    = [0.1509, 0.1973, 0.3279, 0.3406, -0.7112, -0.4572]

ESCALA_L      = 30
ESCALA_S2     = 10
MAX_NUBES_S2  = 20
ZOOM          = 12
STYLE_AREA    = {'color': 'blue', 'fillColor': '#0000ff30', 'weight': 1.5}
STYLE_BBOX    = {'color': 'red',  'fillColor': '#00000000', 'weight': 2.5}
MAP_TITLE     = 'Área de estudio Nevado de Colima'

## La funcon de exportación a Google Drive admite solo el nombre de un folder en raiz de Google Drive, si posibilidad de especificar una subcarpera
#RUTA_IMAGENES = '/content/drive/MyDrive/ANP/Landsat'
RUTA_IMAGENES = 'Colab Data NDC 2020'

# %%
import ee
import math
import json
import geemap
import geopandas as gpd
from shapely.geometry import box
from google.colab import drive
from IPython.display import display, HTML

# Montar Google Drive
drive.mount('/content/drive')

# Autenticar e inicializar GEE
ee.Authenticate()
ee.Initialize(project=GEE_PROJECT)

print("✓ Entorno listo")
# Out:
# Mounted at /content/drive
# ✓ Entorno listo

# %%
# Enmascarar nubes Landsat (L7 y L8)
def mask_clouds(image):
    qa = image.select('QA_PIXEL')
    cloud_shadow_mask = qa.bitwiseAnd(1 << 3).eq(0)
    cloud_mask        = qa.bitwiseAnd(1 << 4).eq(0)
    return image.updateMask(cloud_shadow_mask.And(cloud_mask))

# Enmascarar nubes Sentinel 2
def mask_clouds_s2(img):
    scl  = img.select('SCL')
    mask = scl.neq(3).And(scl.neq(8)).And(scl.neq(9)).And(scl.neq(10))
    return img.updateMask(mask).divide(10000)

#  Corrección topográfica Landsat (L7 y L8)
def correccion_topografica(image, region, bandas_sr, bandas_corr):
    dem        = ee.Image('USGS/SRTMGL1_003').clip(region)
    terreno    = ee.Terrain.products(dem)
    pendiente   = terreno.select('slope').multiply(math.pi / 180)
    orientacion = terreno.select('aspect').multiply(math.pi / 180)
    az_solar   = ee.Number(image.get('SUN_AZIMUTH')).multiply(math.pi / 180)
    elev_solar = ee.Number(image.get('SUN_ELEVATION')).multiply(math.pi / 180)
    cos_i = (
        pendiente.cos().multiply(elev_solar.sin())
        .add(pendiente.sin()
             .multiply(elev_solar.cos())
             .multiply(orientacion.subtract(az_solar).cos()))
    )
    cos_i_safe  = cos_i.max(0.1)
    cos_i_stack = cos_i_safe.rename('cos_i')
    bandas_corr_img = (
        ee.Image.cat([
            image.select(b).multiply(0.0000275).add(-0.2)
                  .divide(cos_i_stack).rename(bandas_corr[i])
            for i, b in enumerate(bandas_sr)
        ])
        .set('SUN_AZIMUTH',   image.get('SUN_AZIMUTH'))
        .set('SUN_ELEVATION', image.get('SUN_ELEVATION'))
        .cast({b: 'double' for b in bandas_corr})
    )
    return bandas_corr_img

# Tasseled Cap
def tasseled_cap(image_corr, bandas_corr, coefs, nombre):
    partes = ee.Image.cat([
        image_corr.select(b).multiply(c)
        for b, c in zip(bandas_corr, coefs)
    ])
    return partes.reduce(ee.Reducer.sum()).rename(nombre)

#  NDVI y TC para L7
def procesar_bandas_l7(mosaico):

    nir  = mosaico.select('SR_B4_corr')
    red  = mosaico.select('SR_B3_corr')
    ndvi = nir.subtract(red).divide(nir.add(red)).rename('NDVI')
    tc_b = tasseled_cap(mosaico, BANDAS_CORR,    TC_BRIGHT,    'TC_Brightness')
    tc_g = tasseled_cap(mosaico, BANDAS_CORR,    TC_GREEN,     'TC_Greenness')
    tc_w = tasseled_cap(mosaico, BANDAS_CORR,    TC_WET,       'TC_Wetness')
    return (ee.Image.cat([ndvi, tc_b, tc_g, tc_w]).clip(region)
              .cast({'NDVI': 'double', 'TC_Brightness': 'double',
                     'TC_Greenness': 'double', 'TC_Wetness': 'double'}))

#  NDVI y TC para L8
def procesar_bandas_l8(mosaico):

    nir  = mosaico.select('SR_B5_corr')
    red  = mosaico.select('SR_B4_corr')
    ndvi = nir.subtract(red).divide(nir.add(red)).rename('NDVI')
    tc_b = tasseled_cap(mosaico, BANDAS_CORR_L8, TC_BRIGHT_L8, 'TC_Brightness')
    tc_g = tasseled_cap(mosaico, BANDAS_CORR_L8, TC_GREEN_L8,  'TC_Greenness')
    tc_w = tasseled_cap(mosaico, BANDAS_CORR_L8, TC_WET_L8,    'TC_Wetness')
    return (ee.Image.cat([ndvi, tc_b, tc_g, tc_w]).clip(region)
              .cast({'NDVI': 'double', 'TC_Brightness': 'double',
                     'TC_Greenness': 'double', 'TC_Wetness': 'double'}))

# NDVI y TC para S2
def procesar_bandas_s2(mosaico):

    nir  = mosaico.select('B8')
    red  = mosaico.select('B4')
    ndvi = nir.subtract(red).divide(nir.add(red)).rename('NDVI')
    tc_b = tasseled_cap(mosaico, BANDAS_S2,      TC_BRIGHT_S2, 'TC_Brightness')
    tc_g = tasseled_cap(mosaico, BANDAS_S2,      TC_GREEN_S2,  'TC_Greenness')
    tc_w = tasseled_cap(mosaico, BANDAS_S2,      TC_WET_S2,    'TC_Wetness')
    return (ee.Image.cat([ndvi, tc_b, tc_g, tc_w]).clip(region)
              .cast({'NDVI': 'double', 'TC_Brightness': 'double',
                     'TC_Greenness': 'double', 'TC_Wetness': 'double'}))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Siguiente bloque permite seleccionar y descargar a Google Drive conjunto de datos para temporada seco y/o humeda en un rectangulo de área de estudio

# %%
gdf = gpd.read_file(RUTA_BBOX)
#gdf = gpd.read_file(RUTA_GEOJSON)

## No queda claro porque se require convertir a geojson_str y despues construir coleccion de elementos desde este str
## ¿Porque no usar directametne el objeto gdf?
geojson_str = gdf.to_crs(epsg=CRS_GEO).to_json()
region = ee.FeatureCollection(json.loads(geojson_str)).geometry()
#region = gdf.to_crs(epsg=CRS_GEO)    # es la linea como se podria cargar capa sin necesidad de conversion a str

def procesar_temporada(nombre_temporada, fecha_ini, fecha_fin):
    print(f"\n── Temporada: {nombre_temporada} ({fecha_ini} → {fecha_fin}) ──")
    fecha_inicio = f'{YEAR}-{fecha_ini}'
    fecha_fin_   = f'{YEAR}-{fecha_fin}'

    col_l7 = (ee.ImageCollection(COLECCION_L7).filterDate(fecha_inicio, fecha_fin_).filterBounds(region))
    col_l8 = (ee.ImageCollection(COLECCION_L8).filterDate(fecha_inicio, fecha_fin_).filterBounds(region))
    col_s2 = (ee.ImageCollection(COLECCION_S2).filterDate(fecha_inicio, fecha_fin_).filterBounds(region)
                .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', MAX_NUBES_S2)))

    n_l7, n_l8, n_s2 = col_l7.size().getInfo(), col_l8.size().getInfo(), col_s2.size().getInfo()

    print(f"  Imágenes Landsat 7: {n_l7}")
    if n_l7 > 0:
        for f in sorted(col_l7.aggregate_array('DATE_ACQUIRED').getInfo()):
            print(f"    · L7 {f}")
    else:
        print("    Sin imágenes L7")

    print(f"  Imágenes Landsat 8: {n_l8}")
    if n_l8 > 0:
        for f in sorted(col_l8.aggregate_array('DATE_ACQUIRED').getInfo()):
            print(f"    · L8 {f}")
    else:
        print("    Sin imágenes L8")

    print(f"  Imágenes Sentinel 2: {n_s2}")
    if n_s2 > 0:
      fechas_s2 = col_s2.aggregate_array('system:time_start').getInfo()
      fechas_s2 = sorted([ee.Date(f).format('YYYY-MM-dd').getInfo() for f in fechas_s2])
    for f in fechas_s2:
        print(f"    · S2 {f}")
    else:
      print("    Sin imágenes S2")

    #  Procesar L7
    img_l7 = None
    mosaico_l7 = None
    if n_l7 > 0:
        col_l7_corr = (col_l7.map(mask_clouds)
                              .map(lambda img: correccion_topografica(img, region, BANDAS_SR, BANDAS_CORR))
                              .select(BANDAS_CORR))
        mosaico_l7 = col_l7_corr.median().clip(region)
        img_l7 = procesar_bandas_l7(mosaico_l7)
        print("  L7 procesado correctamente")
    else:
        print("  L7: Sin datos para esta temporada")

    #  Procesar L8
    img_l8 = None
    mosaico_l8 = None
    if n_l8 > 0:
        col_l8_corr = (col_l8.map(mask_clouds)
                              .map(lambda img: correccion_topografica(img, region, BANDAS_SR_L8, BANDAS_CORR_L8))
                              .select(BANDAS_CORR_L8))
        mosaico_l8 = col_l8_corr.median().clip(region)
        img_l8 = procesar_bandas_l8(mosaico_l8)
        print("  L8 procesado correctamente")
    else:
        print("  L8: Sin datos para esta temporada")

    # Procesar S2 (no se añica corrección topografica)
    img_s2 = None
    mosaico_s2 = None
    if n_s2 > 0:
        col_s2_limpia = col_s2.map(mask_clouds_s2).select(BANDAS_S2)
        mosaico_s2    = col_s2_limpia.median().clip(region)
        img_s2        = procesar_bandas_s2(mosaico_s2)
        print("  S2 procesado correctamente")
    else:
        print("  S2: Sin datos para esta temporada")

    return img_l7, img_l8, img_s2, mosaico_l7, mosaico_l8, mosaico_s2
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Proceso de exportar a Goodle Drive colecciones de 6 bandas e indices (NDVI, 3 componentes de Tasseled Cap) derivados de las imagenes seleccionados, generalizados aplicando la mediana y corregidos topograficamente
#
# Nota V. Sh.:
# * Por el momento no se require guardar en Google Drive Sentinel 2, solo L7 y L8

# %%
img_seca_l7,   img_seca_l8,   img_seca_s2, mosaico_seca_l7,   mosaico_seca_l8,   mosaico_seca_s2   = procesar_temporada('Seca',   *TEMPORADA_SECA)
img_humeda_l7, img_humeda_l8, img_humeda_s2, mosaico_humeda_l7, mosaico_humeda_l8, mosaico_humeda_s2 = procesar_temporada('Húmeda', *TEMPORADA_HUMEDA)

def exportar(imagen, sensor, sufijo, escala):
    if imagen is None:
        print(f"Exportación cancelada para '{sensor}_{sufijo}': imagen no disponible.")
        return
    nombre_tarea = f'{PREFIJO}_{YEAR}_{sensor}_{sufijo}'
    tarea = ee.batch.Export.image.toDrive(
        image          = imagen,
        description    = nombre_tarea,
        folder         = RUTA_IMAGENES,
        fileNamePrefix = nombre_tarea,
        region         = region,
        scale          = escala,
        crs            = f'EPSG:{CRS_UTM}',
        maxPixels      = 1e13
    )
    tarea.start()
    print(f"✓ Tarea iniciada: {nombre_tarea}")

# Exportar medianas de bandas corregidas topograficamente
# con mascara de nubes aplicada

exportar(mosaico_seca_l7,   'L7', 'seca_bandas_corr',   ESCALA_L)
exportar(mosaico_seca_l8,   'L8', 'seca_bandas_corr',   ESCALA_L)
#exportar(mosaico_seca_s2,   'S2', 'seca_bandas_corr',   ESCALA_S2)
exportar(mosaico_humeda_l7, 'L7', 'humeda_bandas_corr', ESCALA_L)
exportar(mosaico_humeda_l8, 'L8', 'humeda_bandas_corr', ESCALA_L)
#exportar(mosaico_humeda_s2, 'S2', 'humeda_bandas_corr', ESCALA_S2)


#  Exportar indices
exportar(img_seca_l7,   'L7', 'seca',   ESCALA_L)
exportar(img_seca_l8,   'L8', 'seca',   ESCALA_L)
#exportar(img_seca_s2,   'S2', 'seca',   ESCALA_S2)
exportar(img_humeda_l7, 'L7', 'humeda', ESCALA_L)
exportar(img_humeda_l8, 'L8', 'humeda', ESCALA_L)
#exportar(img_humeda_s2, 'S2', 'humeda', ESCALA_S2)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ── Temporada: Seca (03-01 → 05-31) ──
#   Imágenes Landsat 7: 12
#     · L7 2020-03-01
#     · L7 2020-03-01
#     · L7 2020-03-17
#     · L7 2020-03-17
#     · L7 2020-04-02
#     · L7 2020-04-02
#     · L7 2020-04-18
#     · L7 2020-04-18
#     · L7 2020-05-04
#     · L7 2020-05-04
#     · L7 2020-05-20
#     · L7 2020-05-20
#   Imágenes Landsat 8: 12
#     · L8 2020-03-09
#     · L8 2020-03-09
#     · L8 2020-03-25
#     · L8 2020-03-25
#     · L8 2020-04-10
#     · L8 2020-04-10
#     · L8 2020-04-26
#     · L8 2020-04-26
#     · L8 2020-05-12
#     · L8 2020-05-12
#     · L8 2020-05-28
#     · L8 2020-05-28
#   Imágenes Sentinel 2: 16
#     · S2 2020-03-03
#     · S2 2020-03-13
#     · S2 2020-03-18
#     · S2 2020-03-23
#     · S2 2020-03-28
#     · S2 2020-04-02
#     · S2 2020-04-07
#     · S2 2020-04-12
#     · S2 2020-04-17
#     · S2 2020-04-27
#     · S2 2020-05-02
#     · S2 2020-05-07
#     · S2 2020-05-12
#     · S2 2020-05-17
#     · S2 2020-05-22
#     · S2 2020-05-27
#     Sin imágenes S2
#   L7 procesado correctamente
#   L8 procesado correctamente
#   S2 procesado correctamente
#
# ── Temporada: Húmeda (08-01 → 11-30) ──
#   Imágenes Landsat 7: 15
#     · L7 2020-08-08
#     · L7 2020-08-08
#     · L7 2020-08-24
#     · L7 2020-08-24
#     · L7 2020-09-09
#     · L7 2020-09-09
#     · L7 2020-09-25
#     · L7 2020-09-25
#     · L7 2020-10-11
#     · L7 2020-10-27
#     · L7 2020-10-27
#     · L7 2020-11-12
#     · L7 2020-11-12
#     · L7 2020-11-28
#     · L7 2020-11-28
#   Imágenes Landsat 8: 12
#     · L8 2020-08-16
#     · L8 2020-08-16
#     · L8 2020-09-01
#     · L8 2020-09-01
#     · L8 2020-09-17
#     · L8 2020-09-17
#     · L8 2020-10-03
#     · L8 2020-10-03
#     · L8 2020-10-19
#     · L8 2020-10-19
#     · L8 2020-11-20
#     · L8 2020-11-20
#   Imágenes Sentinel 2: 16
#     · S2 2020-08-05
#     · S2 2020-08-10
#     · S2 2020-08-15
#     · S2 2020-09-14
#     · S2 2020-09-24
#     · S2 2020-10-04
#     · S2 2020-10-09
#     · S2 2020-10-14
#     · S2 2020-10-24
#     · S2 2020-10-29
#     · S2 2020-11-03
#     · S2 2020-11-08
#     · S2 2020-11-13
#     · S2 2020-11-18
#     · S2 2020-11-23
#     · S2 2020-11-28
#     Sin imágenes S2
#   L7 procesado correctamente
#   L8 procesado correctamente
#   S2 procesado correctamente
# ✓ Tarea iniciada: NCL_2020_L7_seca_bandas_corr
# ✓ Tarea iniciada: NCL_2020_L8_seca_bandas_corr
# ✓ Tarea iniciada: NCL_2020_L7_humeda_bandas_corr
# ✓ Tarea iniciada: NCL_2020_L8_humeda_bandas_corr
# ✓ Tarea iniciada: NCL_2020_L7_seca
# ✓ Tarea iniciada: NCL_2020_L8_seca
# ✓ Tarea iniciada: NCL_2020_L7_humeda
# ✓ Tarea iniciada: NCL_2020_L8_humeda

# %% [markdown]
# ## Calcular estadisticas de capas y de indices
#
# Nota V. Sh.:
# * Las estadisticas se requiere separar de la generación de mapas interactivos
# * Es util tener estadisticas tanto de indices como de las capas individuales corregidas

# %%
def calcular_estadisticas_indices(imagen, sensor, temporada):
    if imagen is None:
        print(f"  ℹ️ No hay datos para {sensor} - {temporada}")
        return
    nombre_base = f'{YEAR} {temporada} {sensor}'
    # Calcular y mostrar estadísticas
    print(f"\n{'='*60}")
    print(f"📊 Estadísticas para {nombre_base}")
    print(f"{'='*60}")

    for banda in ['NDVI', 'TC_Brightness', 'TC_Greenness', 'TC_Wetness']:
        stats = imagen.select(banda).reduceRegion(
            reducer=ee.Reducer.minMax(),
            geometry=region,
            scale=30,
            maxPixels=1e9
        ).getInfo()

        # Combine the mean and standard deviation reducers.
        reducer_comb = ee.Reducer.mean().combine(
              reducer2=ee.Reducer.stdDev(), sharedInputs=True
        )
        stats2 = imagen.select(banda).reduceRegion(
            reducer=reducer_comb,
            geometry=region,
            scale=30,
            maxPixels=1e9
        ).getInfo()

        min_val = stats.get(f'{banda}_min', 0)
        max_val = stats.get(f'{banda}_max', 0)
        mean_val = stats2.get(f'{banda}_mean', 0)
        std_val = stats2.get(f'{banda}_stdDev', 0)

        print(f"  {banda:>15}: min = {min_val:>8.4f} | max = {max_val:>8.4f} | rango = {max_val - min_val:>8.4f} | promedio = {mean_val:>8.4f} | SD = {std_val:>8.4f}")

    print(f"{'='*60}\n")


def calcular_estadisticas_bandas(imagen, sensor, temporada, bandas):
    if imagen is None:
        print(f"  ℹ️ No hay datos para {sensor} - {temporada}")
        return
    nombre_base = f'{YEAR} {temporada} {sensor}'
    # Calcular y mostrar estadísticas
    print(f"\n{'='*60}")
    print(f"📊 Estadísticas para {nombre_base}")
    print(f"{'='*60}")

    for banda in bandas:
        stats = imagen.select(banda).reduceRegion(
            reducer=ee.Reducer.minMax(),
            geometry=region,
            scale=30,
            maxPixels=1e9
        ).getInfo()

        # Combine the mean and standard deviation reducers.
        reducer_comb = ee.Reducer.mean().combine(
              reducer2=ee.Reducer.stdDev(), sharedInputs=True
        )
        stats2 = imagen.select(banda).reduceRegion(
            reducer=reducer_comb,
            geometry=region,
            scale=30,
            maxPixels=1e9
        ).getInfo()

        min_val = stats.get(f'{banda}_min', 0)
        max_val = stats.get(f'{banda}_max', 0)
        mean_val = stats2.get(f'{banda}_mean', 0)
        std_val = stats2.get(f'{banda}_stdDev', 0)

        print(f"  {banda:>15}: min = {min_val:>8.4f} | max = {max_val:>8.4f} | rango = {max_val - min_val:>8.4f} | promedio = {mean_val:>8.4f} | SD = {std_val:>8.4f}")

    print(f"{'='*60}\n")


print("Agregando capas al mapa (2020):")
calcular_estadisticas_indices(img_seca_l7, 'L7', 'Seca')
calcular_estadisticas_bandas(mosaico_seca_l7, 'L7', 'Seca', BANDAS_CORR)

calcular_estadisticas_indices(img_humeda_l7, 'L7', 'Húmeda')
calcular_estadisticas_bandas(mosaico_humeda_l7, 'L7', 'Húmeda', BANDAS_CORR)

calcular_estadisticas_indices(img_seca_l8, 'L8', 'Seca')
calcular_estadisticas_bandas(mosaico_seca_l8, 'L8', 'Seca', BANDAS_CORR_L8)

calcular_estadisticas_indices(img_humeda_l8, 'L8', 'Húmeda')
calcular_estadisticas_bandas(mosaico_humeda_l8, 'L8', 'Húmeda', BANDAS_CORR_L8)

calcular_estadisticas_indices(img_seca_s2, 'S2', 'Seca')
calcular_estadisticas_bandas(mosaico_seca_s2, 'S2', 'Seca', BANDAS_S2)

calcular_estadisticas_indices(img_humeda_s2, 'S2', 'Húmeda')
calcular_estadisticas_bandas(mosaico_seca_s2, 'S2', 'Húmeda', BANDAS_S2)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Agregando capas al mapa (2020):
#
# ============================================================
# 📊 Estadísticas para 2020 Seca L7
# ============================================================
#              NDVI: min =  -0.0049 | max =   0.9184 | rango =   0.9233 | promedio =   0.6849 | SD =   0.1750
#     TC_Brightness: min =   0.0012 | max =   2.9338 | rango =   2.9325 | promedio =   0.3553 | SD =   0.0825
#      TC_Greenness: min =  -0.2288 | max =   1.4728 | rango =   1.7015 | promedio =   0.1392 | SD =   0.0789
#        TC_Wetness: min =  -1.5708 | max =   0.0081 | rango =   1.5789 | promedio =  -0.1528 | SD =   0.0571
# ============================================================
#
#
# ============================================================
# 📊 Estadísticas para 2020 Seca L7
# ============================================================
#        SR_B1_corr: min =   0.0074 | max =   0.4112 | rango =   0.4038 | promedio =   0.0398 | SD =   0.0175
#        SR_B2_corr: min =   0.0139 | max =   0.5596 | rango =   0.5456 | promedio =   0.0614 | SD =   0.0215
#        SR_B3_corr: min =   0.0093 | max =   0.6942 | rango =   0.6849 | promedio =   0.0595 | SD =   0.0311
#        SR_B4_corr: min =   0.0524 | max =   2.9724 | rango =   2.9201 | promedio =   0.3345 | SD =   0.0943
#        SR_B5_corr: min =   0.0289 | max =   1.7905 | rango =   1.7616 | promedio =   0.1956 | SD =   0.0593
#        SR_B7_corr: min =   0.0095 | max =   1.1247 | rango =   1.1152 | promedio =   0.1018 | SD =   0.0446
# ============================================================
#
#
# ============================================================
# 📊 Estadísticas para 2020 Húmeda L7
# ============================================================
#              NDVI: min =   0.0023 | max =   1.2006 | rango =   1.1983 | promedio =   0.7712 | SD =   0.1487
#     TC_Brightness: min =   0.0015 | max =   3.8033 | rango =   3.8018 | promedio =   0.3846 | SD =   0.1297
#      TC_Greenness: min =  -0.3229 | max =   1.9144 | rango =   2.2373 | promedio =   0.1871 | SD =   0.0910
#        TC_Wetness: min =  -2.0270 | max =   0.0698 | rango =   2.0967 | promedio =  -0.1424 | SD =   0.0528
# ============================================================
#
#
# ============================================================
# 📊 Estadísticas para 2020 Húmeda L7
# ============================================================
#        SR_B1_corr: min =  -0.0533 | max =   0.8339 | rango =   0.8872 | promedio =   0.0382 | SD =   0.0215
#        SR_B2_corr: min =  -0.0021 | max =   0.8204 | rango =   0.8225 | promedio =   0.0595 | SD =   0.0258
#        SR_B3_corr: min =  -0.0321 | max =   0.6999 | rango =   0.7320 | promedio =   0.0474 | SD =   0.0282
#        SR_B4_corr: min =   0.0372 | max =   3.6834 | rango =   3.6462 | promedio =   0.3891 | SD =   0.1421
#        SR_B5_corr: min =  -0.0701 | max =   2.4017 | rango =   2.4717 | promedio =   0.1926 | SD =   0.0650
#        SR_B7_corr: min =  -0.0475 | max =   1.2362 | rango =   1.2837 | promedio =   0.0897 | SD =   0.0389
# ============================================================
#
#
# ============================================================
# 📊 Estadísticas para 2020 Seca L8
# ============================================================
#              NDVI: min =  -0.0150 | max =   0.9096 | rango =   0.9246 | promedio =   0.6958 | SD =   0.1828
#     TC_Brightness: min =   0.0014 | max =   3.2368 | rango =   3.2354 | promedio =   0.3525 | SD =   0.0756
#      TC_Greenness: min =  -0.9481 | max =   0.0175 | rango =   0.9656 | promedio =  -0.0565 | SD =   0.0401
#        TC_Wetness: min =  -0.0129 | max =   0.5129 | rango =   0.5258 | promedio =   0.0551 | SD =   0.0191
# ============================================================
#
#
# ============================================================
# 📊 Estadísticas para 2020 Seca L8
# ============================================================
#        SR_B2_corr: min =  -0.0033 | max =   0.3606 | rango =   0.3639 | promedio =   0.0295 | SD =   0.0155
#        SR_B3_corr: min =   0.0125 | max =   0.5713 | rango =   0.5588 | promedio =   0.0581 | SD =   0.0193
#        SR_B4_corr: min =   0.0107 | max =   0.7591 | rango =   0.7484 | promedio =   0.0555 | SD =   0.0300
#        SR_B5_corr: min =   0.0411 | max =   3.3584 | rango =   3.3172 | promedio =   0.3276 | SD =   0.0866
#        SR_B6_corr: min =   0.0290 | max =   2.0557 | rango =   2.0267 | promedio =   0.1940 | SD =   0.0554
#        SR_B7_corr: min =   0.0143 | max =   1.2853 | rango =   1.2709 | promedio =   0.1041 | SD =   0.0429
# ============================================================
#
#
# ============================================================
# 📊 Estadísticas para 2020 Húmeda L8
# ============================================================
#              NDVI: min =  -0.0163 | max =   1.3374 | rango =   1.3537 | promedio =   0.7963 | SD =   0.1555
#     TC_Brightness: min =   0.0014 | max =   2.7494 | rango =   2.7480 | promedio =   0.3313 | SD =   0.0946
#      TC_Greenness: min =  -0.5860 | max =   0.0374 | rango =   0.6234 | promedio =  -0.0378 | SD =   0.0244
#        TC_Wetness: min =  -0.0370 | max =   0.4848 | rango =   0.5218 | promedio =   0.0558 | SD =   0.0214
# ============================================================
#
#
# ============================================================
# 📊 Estadísticas para 2020 Húmeda L8
# ============================================================
#        SR_B2_corr: min =  -0.1070 | max =   0.3261 | rango =   0.4332 | promedio =   0.0180 | SD =   0.0148
#        SR_B3_corr: min =  -0.0266 | max =   0.4289 | rango =   0.4555 | promedio =   0.0468 | SD =   0.0184
#        SR_B4_corr: min =  -0.0140 | max =   0.5589 | rango =   0.5728 | promedio =   0.0362 | SD =   0.0229
#        SR_B5_corr: min =   0.0265 | max =   2.9426 | rango =   2.9161 | promedio =   0.3441 | SD =   0.1123
#        SR_B6_corr: min =   0.0150 | max =   1.5053 | rango =   1.4903 | promedio =   0.1729 | SD =   0.0494
#        SR_B7_corr: min =   0.0067 | max =   0.9021 | rango =   0.8954 | promedio =   0.0832 | SD =   0.0315
# ============================================================
#
#
# ============================================================
# 📊 Estadísticas para 2020 Seca S2
# ============================================================
#              NDVI: min =  -0.1925 | max =   0.9169 | rango =   1.1093 | promedio =   0.6725 | SD =   0.2033
#     TC_Brightness: min =   0.0527 | max =   0.7742 | rango =   0.7214 | promedio =   0.3144 | SD =   0.0555
#      TC_Greenness: min =  -0.1071 | max =   0.4067 | rango =   0.5138 | promedio =   0.1454 | SD =   0.0679
#        TC_Wetness: min =  -0.2634 | max =   0.0554 | rango =   0.3188 | promedio =  -0.0433 | SD =   0.0421
# ============================================================
#
#
# ============================================================
# 📊 Estadísticas para 2020 Seca S2
# ============================================================
#                B2: min =   0.0052 | max =   0.2694 | rango =   0.2642 | promedio =   0.0364 | SD =   0.0176
#                B3: min =   0.0079 | max =   0.3007 | rango =   0.2928 | promedio =   0.0573 | SD =   0.0184
#                B4: min =   0.0057 | max =   0.3394 | rango =   0.3337 | promedio =   0.0515 | SD =   0.0297
#                B8: min =   0.0243 | max =   0.6538 | rango =   0.6296 | promedio =   0.2769 | SD =   0.0678
#               B11: min =   0.0398 | max =   0.4649 | rango =   0.4251 | promedio =   0.1780 | SD =   0.0442
#               B12: min =   0.0170 | max =   0.3363 | rango =   0.3194 | promedio =   0.0979 | SD =   0.0371
# ============================================================
#
#
# ============================================================
# 📊 Estadísticas para 2020 Húmeda S2
# ============================================================
#              NDVI: min =  -0.0783 | max =   0.9348 | rango =   1.0131 | promedio =   0.7666 | SD =   0.1676
#     TC_Brightness: min =   0.0376 | max =   0.9906 | rango =   0.9530 | promedio =   0.2533 | SD =   0.0582
#      TC_Greenness: min =  -0.0908 | max =   0.7334 | rango =   0.8242 | promedio =   0.1428 | SD =   0.0563
#        TC_Wetness: min =  -0.1885 | max =   0.0545 | rango =   0.2430 | promedio =  -0.0220 | SD =   0.0207
# ============================================================
#
#
# ============================================================
# 📊 Estadísticas para 2020 Húmeda S2
# ============================================================
#                B2: min =   0.0052 | max =   0.2694 | rango =   0.2642 | promedio =   0.0364 | SD =   0.0176
#                B3: min =   0.0079 | max =   0.3007 | rango =   0.2928 | promedio =   0.0573 | SD =   0.0184
#                B4: min =   0.0057 | max =   0.3394 | rango =   0.3337 | promedio =   0.0515 | SD =   0.0297
#                B8: min =   0.0243 | max =   0.6538 | rango =   0.6296 | promedio =   0.2769 | SD =   0.0678
#               B11: min =   0.0398 | max =   0.4649 | rango =   0.4251 | promedio =   0.1780 | SD =   0.0442
#               B12: min =   0.0170 | max =   0.3363 | rango =   0.3194 | promedio =   0.0979 | SD =   0.0371
# ============================================================

# %% [markdown]
# ## Visualización de las capas de datos seleccionadas en un mapa interactiva

# %%
gdf_bbox = gpd.read_file(RUTA_BBOX).to_crs(epsg=CRS_GEO)
gdf_area = gpd.read_file(RUTA_GEOJSON).to_crs(epsg=CRS_GEO)

# Recalcular centroide
# Calcular centroide en WGS84
# FIX: calcular centroide en CRS proyectado, luego volver a WGS84
centroid_proj = gdf_bbox.to_crs(epsg=3857).dissolve().centroid.iloc[0]
centroid = gpd.GeoSeries([centroid_proj], crs=3857).to_crs(epsg=4326).iloc[0]

#  MAPA
mapa = geemap.Map(height="950px", width="100%",layer_ctrl=False)
mapa.add_gdf(gdf_area, layer_name='ANP – Polígono',    style=STYLE_AREA)
mapa.set_center(centroid.x, centroid.y, ZOOM)
mapa.add_gdf(gdf_bbox, layer_name='ANP – Bounding Box', style=STYLE_BBOX)
mapa.add_basemap('ROADMAP')

# Landsat 7 TM (2020)
VIS_L7_SECA = {
    'NDVI': {'min': -0.60, 'max': 0.86, 'palette': ['#d73027', '#fee08b', '#1a9850']},
    'TC_Brightness': {'min': 0.00, 'max': 0.87, 'palette': ['white', 'brown']},
    'TC_Greenness': {'min': -0.22, 'max': 0.29, 'palette': ['white', 'darkgreen']},
    'TC_Wetness': {'min': -0.49, 'max': 0.11, 'palette': ['brown', 'white', 'blue']}
}

VIS_L7_HUMEDA = {
    'NDVI': {'min': -0.24, 'max': 0.90, 'palette': ['#d73027', '#fee08b', '#1a9850']},
    'TC_Brightness': {'min': 0.00, 'max': 1.16, 'palette': ['white', 'brown']},
    'TC_Greenness': {'min': -0.20, 'max': 0.60, 'palette': ['white', 'darkgreen']},
    'TC_Wetness': {'min': -0.55, 'max': 0.13, 'palette': ['brown', 'white', 'blue']}
}

# Landsat 8 ETM+ (2020)
VIS_L8_SECA = {
    'NDVI': {'min': -0.32, 'max': 0.88, 'palette': ['#d73027', '#fee08b', '#1a9850']},
    'TC_Brightness': {'min': 0.00, 'max': 0.95, 'palette': ['white', 'brown']},
    'TC_Greenness': {'min': -0.27, 'max': 0.03, 'palette': ['white', 'darkgreen']},
    'TC_Wetness': {'min': -0.03, 'max': 0.29, 'palette': ['brown', 'white', 'blue']}
}

VIS_L8_HUMEDA = {
    'NDVI': {'min': -0.34, 'max': 0.91, 'palette': ['#d73027', '#fee08b', '#1a9850']},
    'TC_Brightness': {'min': 0.00, 'max': 1.05, 'palette': ['white', 'brown']},
    'TC_Greenness': {'min': -0.28, 'max': 0.05, 'palette': ['white', 'darkgreen']},
    'TC_Wetness': {'min': -0.03, 'max': 0.24, 'palette': ['brown', 'white', 'blue']}
}


# Sentinel 2 (2020)
VIS_S2_SECA = {
    'NDVI': {'min': -0.36, 'max': 0.90, 'palette': ['#d73027', '#fee08b', '#1a9850']},
    'TC_Brightness': {'min': 0.03, 'max': 1.13, 'palette': ['white', 'brown']},
    'TC_Greenness': {'min': -0.24, 'max': 0.38, 'palette': ['white', 'darkgreen']},
    'TC_Wetness': {'min': -0.33, 'max': 0.26, 'palette': ['brown', 'white', 'blue']}
}

VIS_S2_HUMEDA = {
    'NDVI': {'min': -0.40, 'max': 0.91, 'palette': ['#d73027', '#fee08b', '#1a9850']},
    'TC_Brightness': {'min': 0.02, 'max': 1.00, 'palette': ['white', 'brown']},
    'TC_Greenness': {'min': -0.18, 'max': 0.37, 'palette': ['white', 'darkgreen']},
    'TC_Wetness': {'min': -0.32, 'max': 0.24, 'palette': ['brown', 'white', 'blue']}
}

VISUALIZACION_2020 = {
    'L7': {
        'Seca': VIS_L7_SECA,
        'Húmeda': VIS_L7_HUMEDA
    },
    'L8': {
        'Seca': VIS_L8_SECA,
        'Húmeda': VIS_L8_HUMEDA
    },
    'S2': {
        'Seca': VIS_S2_SECA,
        'Húmeda': VIS_S2_HUMEDA
    }
}

def agregar_capas_2020(imagen, sensor, temporada):
    """Agrega capas al mapa con parámetros de visualización para 2020"""
    if imagen is None:
        print(f"  ℹ️ No hay datos para {sensor} - {temporada}")
        return

    vis = VISUALIZACION_2020[sensor][temporada]
    nombre_base = f'2020 {temporada} {sensor}'

    # Definir qué capa mostrar inicialmente (ejemplo: L7 Seca)
    mostrar_inicial = (temporada == 'Seca' and sensor == 'L7')

    # Agregar capas
    for banda in ['NDVI', 'TC_Brightness', 'TC_Greenness', 'TC_Wetness']:
        mapa.addLayer(
            imagen.select(banda),
            vis[banda],
            f'{nombre_base} – {banda}',
            shown=(mostrar_inicial and banda == 'NDVI')
        )

print(f"Agregando capas al mapa {YEAR}:")
agregar_capas_2020(img_seca_l7, 'L7', 'Seca')
agregar_capas_2020(img_humeda_l7, 'L7', 'Húmeda')
agregar_capas_2020(img_seca_l8, 'L8', 'Seca')
agregar_capas_2020(img_humeda_l8, 'L8', 'Húmeda')
#agregar_capas_2020(img_seca_s2, 'S2', 'Seca')
#agregar_capas_2020(img_humeda_s2, 'S2', 'Húmeda')

mapa.addLayerControl()
print(f"\n✅ Visualización completada {YEAR}")
display(mapa)
